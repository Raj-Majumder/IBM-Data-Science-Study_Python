# %%
def calculate_sum(x,y):
 try:
    x_parity = "an odd" if (x % 2 !=0) else "an even"
    y_parity = "an odd" if (y % 2 !=0) else "an even"

    print(f"The calculated sum is: {x + y: .2f}")
    print(f"The sum was made with x value at {x} which is {x_parity} number and y value at  {y} which is {y_parity} number.")
    
    if x> 5.5 and  y> 4.5:
        if (x % 2 !=0) and (y % 2 !=0):
            
            print("Both numbers meet the size criteria AND are odd integers.")
        else:
            print("Both numbers meet the size criteria, but not both are odd integers.")
    else:
        print("One or both numbers do not meet the size criteria")

 except TypeError:
    print("\n!!! ERROR: Invalid input type !!!")
    print("Please ensure both x and y are numbers (integers or floats).")
 except Exception as e:
    print(f"\n!!! An unexpected error occurred: {e} !!!")

# %%
 x = "four"
 y = 3

calculate_sum(x,y)
# Out:
# !!! ERROR: Invalid input type !!!
# Please ensure both x and y are numbers (integers or floats).
